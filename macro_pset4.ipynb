# %%
import jax
import jax.numpy as jnp
import numpy as np
from typing import Callable, Tuple
import pandas as pd

jax.config.update("jax_enable_x64", True)

# %%
beta = 0.98
alpha = 0.3
delta = 0.075

k_star = ((1 / beta - 1 + delta) / alpha) ** (1 / (alpha - 1))
print(f"{k_star=:0.3f}")
# Out:
# k_star=5.138

# %% [markdown]
# # Extended Path Algorithm

# %%
def F(k, k_prime):
    return jnp.log(jnp.power(k, alpha) + (1 - delta) * k - k_prime)


dF_1 = jax.grad(F, argnums=0)
dF_2 = jax.grad(F, argnums=1)


def q(k, k_p, k_p2):
    return dF_2(k, k_p) + beta * dF_1(k_p, k_p2)


def Q(k0, phi):
    lower_tail = jnp.array([q(k0, phi[0], phi[1])])
    interior = jax.vmap(q)(phi[:-2], phi[1:-1], phi[2:])
    upper_tail = jnp.array([q(phi[-2], phi[-1], k_star)])

    return jnp.concatenate([lower_tail, interior, upper_tail])

# %%
k0 = 0.95 * k_star
phi = jnp.repeat(k_star, 200).astype(jnp.float64)


def newton_extended_path(k0, phi):
    tol = 1e-14
    iter = 0
    dist = jnp.linalg.norm(Q(k0, phi))

    while dist > tol:
        print(f"{iter=}: {dist=}")
        J = jax.jacrev(lambda x: Q(k0, x))(phi)

        phi = phi - (jnp.linalg.inv(J) @ Q(k0, phi))
        dist = jnp.linalg.norm(Q(k0, phi))

        iter += 1

    return phi


phi_k95 = newton_extended_path(0.95 * k_star, phi)
phi_k90 = newton_extended_path(0.90 * k_star, phi_k95)
phi_k80 = newton_extended_path(0.80 * k_star, phi_k90)
phi_k60 = newton_extended_path(0.60 * k_star, phi_k80)
# Out:
# iter=0: dist=Array(0.21327126, dtype=float64)
# iter=1: dist=Array(0.03101912, dtype=float64)
# iter=2: dist=Array(0.00082659, dtype=float64)
# iter=3: dist=Array(6.12335192e-07, dtype=float64)
# iter=4: dist=Array(3.37293575e-13, dtype=float64)
# iter=0: dist=Array(0.2279395, dtype=float64)
# iter=1: dist=Array(0.03400567, dtype=float64)
# iter=2: dist=Array(0.00095784, dtype=float64)
# iter=3: dist=Array(7.94493024e-07, dtype=float64)
# iter=4: dist=Array(5.48087794e-13, dtype=float64)
# iter=0: dist=Array(0.6902485, dtype=float64)
# iter=1: dist=Array(0.19663463, dtype=float64)
# iter=2: dist=Array(0.02482011, dtype=float64)
# iter=3: dist=Array(0.0004807, dtype=float64)
# iter=4: dist=Array(1.85948071e-07, dtype=float64)
# iter=5: dist=Array(2.82930487e-14, dtype=float64)
# iter=0: dist=Array(29.11101042, dtype=float64)
# iter=1: dist=Array(14.33066245, dtype=float64)
# iter=2: dist=Array(6.94009305, dtype=float64)
# iter=3: dist=Array(3.24492233, dtype=float64)
# iter=4: dist=Array(1.40107123, dtype=float64)
# iter=5: dist=Array(0.49845983, dtype=float64)
# iter=6: dist=Array(0.10840294, dtype=float64)
# iter=7: dist=Array(0.00710789, dtype=float64)
# iter=8: dist=Array(3.37202885e-05, dtype=float64)
# iter=9: dist=Array(7.64619822e-10, dtype=float64)

# %%
def speed_of_adjustment_extended_path(k0, phi):
    gap_closed = k0 + 0.99 * abs(k0 - k_star)
    return int(jnp.min(jnp.where(phi > gap_closed)[0]))


extended_path_results = {
    "k0=0.95*kstar": speed_of_adjustment_extended_path(0.95 * k_star, phi_k95),
    "k0=0.90*kstar": speed_of_adjustment_extended_path(0.90 * k_star, phi_k90),
    "k0=0.80*kstar": speed_of_adjustment_extended_path(0.80 * k_star, phi_k80),
    "k0=0.60*kstar": speed_of_adjustment_extended_path(0.60 * k_star, phi_k60),
}

# %%
extended_path_results
# Out:
# {'k0=0.95*kstar': 39,
#  'k0=0.90*kstar': 39,
#  'k0=0.80*kstar': 40,
#  'k0=0.60*kstar': 40}

# %% [markdown]
# # Value Function Iteration

# %%
k_bar = 15
N = 10_000

eps = 1e-4
k_init = np.linspace(0, k_bar, N) + eps
k_init = k_init.reshape(N, 1)

k_prime = np.linspace(0, k_bar, N) + eps
k_prime = k_prime.reshape(1, N)

constants = {
    "k": k_init,
    "k_prime": k_prime,
}

# %%
def calculate_value_grid(
    k: np.ndarray,
    k_prime: np.ndarray,
    v_next: np.ndarray,
) -> np.ndarray:
    """Computes a grid of utility payoffs

    Parameters
    ----------
        k np.ndarray:
            N X 1 array of values to compute K_init over

        k_prime np.ndarray:
            1 X N array of values to compute K_prime over

    Returns
    -------
        N X N  array of computed values

    """
    c = k**alpha + (1 - delta) * k - k_prime
    U = np.full_like(c, -np.inf, dtype=float)

    # ensures k_prime <= k^alpha + (1-delta) * k
    feasibilty_mask = c > 0

    U[feasibilty_mask] = np.log(c[feasibilty_mask])
    v_next_col = np.asarray(v_next).reshape(1, -1)

    return U + beta * v_next_col


def bellman_operator(
    value_function: Callable, v_arr: np.ndarray, **kwargs
) -> Tuple[np.ndarray, np.ndarray]:
    """Computes a single iteration of the bellman operator.

    Parameters
    ----------
    value_function: callable
        value_function

    v_next_arr: np.ndarray
        (N,) array of previous maximum guess

    **kwargs
        keyword arguments to properly specify the value_function grid
    """
    v_mat = value_function(v_next=v_arr, **kwargs)

    argmax_v_mat = np.argmax(v_mat, axis=1)
    v_arr_next = np.max(v_mat, axis=1)

    return argmax_v_mat, v_arr_next


def sup_norm_dist(x: np.ndarray, y: np.ndarray) -> float:
    return np.max(np.abs(x - y))


def l2_norm(x: np.ndarray, y: np.ndarray) -> float:
    return np.sqrt(np.sum(np.power(x - y, 2)))


def infinite_horizon_value_function_iteration(
    convergence_eps: float, d: Callable[[np.ndarray, np.ndarray], float]
):
    """Solves the infinite horizon value-function iteration until convergence.

    Parameters
    ----------
    convergence_eps: float
        epsilon used to define convergence

    d: Callable[np.ndarray, np.ndarray] -> float
        distance function used to define convergence
    """

    # initialize guess
    v_max_array = np.full(N, 2)
    i = 1

    while True:
        argmax_v_mat, v_max_array_new = bellman_operator(
            calculate_value_grid, v_max_array, **constants
        )

        dist = d(v_max_array_new, v_max_array)
        print(f"Iteration {i}, Distance {dist}")

        v_max_array = v_max_array_new
        i += 1

        if dist <= convergence_eps:
            break

    return argmax_v_mat, v_max_array


def g(k, optimal_index):
    """Discretized policy function"""
    k_discrete_idx = np.argmin(np.abs(k_init - k))
    return k_prime.ravel()[optimal_index[k_discrete_idx]]


def simulate_infinite(k0, T_max, argmax_v_mat):
    """Solve the infinite horizon problem"""
    # The homeworks asks to go to 1e-10 tolerance, but I don't have time for that, results are stable enough here
    ks = np.zeros(T_max)
    cs = np.zeros(T_max - 1)

    ks[0] = k0

    for t in range(1, T_max):
        ks[t] = g(ks[t - 1], argmax_v_mat)
        cs[t - 1] = ks[t - 1] ** alpha + (1 - delta) * ks[t - 1] - ks[t]

    return ks, cs

# %%
argmax_v_mat, _ = infinite_horizon_value_function_iteration(
    convergence_eps=1e-3, d=l2_norm
)
# Out:
# Iteration 1, Distance 205.56806804587427
# Iteration 2, Distance 98.28254686553211
# Iteration 3, Distance 67.25497972121823
# Iteration 4, Distance 50.5617319971315
# Iteration 5, Distance 40.03695647549519
# Iteration 6, Distance 32.82522932150634
# Iteration 7, Distance 27.61945025809437
# Iteration 8, Distance 23.724769915978253
# Iteration 9, Distance 20.733740462698975
# Iteration 10, Distance 18.38995518506923
# Iteration 11, Distance 16.523226005761693
# Iteration 12, Distance 15.015824374372267
# Iteration 13, Distance 13.783618166629463
# Iteration 14, Distance 12.764935416929537
# Iteration 15, Distance 11.91366321897913
# Iteration 16, Distance 11.19478849647875
# Iteration 17, Distance 10.58140915320985
# Iteration 18, Distance 10.052663512801706
# Iteration 19, Distance 9.592252962702524
# Iteration 20, Distance 9.187369058171512
# Iteration 21, Distance 8.827890357948352
# Iteration 22, Distance 8.505780648429873
# Iteration 23, Distance 8.214630600645835
# Iteration 24, Distance 7.949307143118487
# Iteration 25, Distance 7.7056802000886035
# Iteration 26, Distance 7.480408201224662
# Iteration 27, Distance 7.270780080854734
# Iteration 28, Distance 7.0745809500747345
# Iteration 29, Distance 6.8899983986615
# Iteration 30, Distance 6.715534432509176
# Iteration 31, Distance 6.549950041209973
# Iteration 32, Distance 6.39221478965816
# Iteration 33, Distance 6.241464435987874
# Iteration 34, Distance 6.09697269480882
# Iteration 35, Distance 5.95812461132095
# Iteration 36, Distance 5.824399058859927
# Iteration 37, Distance 5.695350581525989
# Iteration 38, Distance 5.570596180861675
# Iteration 39, Distance 5.4498048826198575
# Iteration 40, Distance 5.332690089313321
# Iteration 41, Distance 5.219002643449977
# Iteration 42, Distance 5.108523354216508
# Iteration 43, Distance 5.001060055133558
# Iteration 44, Distance 4.8964427158644135
# Iteration 45, Distance 4.794520624763704
# Iteration 46, Distance 4.695158342851203
# Iteration 47, Distance 4.598235985163264
# Iteration 48, Distance 4.503643946165534
# Iteration 49, Distance 4.411284553083922
# Iteration 50, Distance 4.3210677960332236
# Iteration 51, Distance 4.232911488792879
# Iteration 52, Distance 4.146743183161866
# Iteration 53, Distance 4.062491519350225
# Iteration 54, Distance 3.9800942097416243
# Iteration 55, Distance 3.8994919718832026
# Iteration 56, Distance 3.8206295013223457
# Iteration 57, Distance 3.743457219662216
# Iteration 58, Distance 3.6679248326925413
# Iteration 59, Distance 3.593987189496235
# Iteration 60, Distance 3.521603243221324
# Iteration 61, Distance 3.4507304011020876
# Iteration 62, Distance 3.3813313865750323
# Iteration 63, Distance 3.313370547838133
# Iteration 64, Distance 3.246810578529956
# Iteration 65, Distance 3.1816194021964987
# Iteration 66, Distance 3.117764429232938
# Iteration 67, Distance 3.055213603452252
# Iteration 68, Distance 2.993941230607688
# Iteration 69, Distance 2.9339147978630473
# Iteration 70, Distance 2.8751065495044026
# Iteration 71, Distance 2.817492072379459
# Iteration 72, Distance 2.7610432732598587
# Iteration 73, Distance 2.705736687036554
# Iteration 74, Distance 2.6515468880768
# Iteration 75, Distance 2.5984507476565604
# Iteration 76, Distance 2.5464246529766594
# Iteration 77, Distance 2.4954479708278607
# Iteration 78, Distance 2.4454946954347623
# Iteration 79, Distance 2.396546511593792
# Iteration 80, Distance 2.3485820712774292
# Iteration 81, Distance 2.30158048819103
# Iteration 82, Distance 2.2555248103049856
# Iteration 83, Distance 2.2103921380738556
# Iteration 84, Distance 2.166164692982026
# Iteration 85, Distance 2.1228258685713377
# Iteration 86, Distance 2.0803546964672908
# Iteration 87, Distance 2.0387337852073517
# Iteration 88, Distance 1.9979477135060784
# Iteration 89, Distance 1.9579801039154512
# Iteration 90, Distance 1.9188120526275345
# Iteration 91, Distance 1.8804275473858236
# Iteration 92, Distance 1.8428118349937441
# Iteration 93, Distance 1.8059497244061005
# Iteration 94, Distance 1.7698270264900418
# Iteration 95, Distance 1.7344267417155157
# Iteration 96, Distance 1.699734145803396
# Iteration 97, Distance 1.6657353040858789
# Iteration 98, Distance 1.6324168239303596
# Iteration 99, Distance 1.5997655185913493
# Iteration 100, Distance 1.5677682679146066
# Iteration 101, Distance 1.5364118720971398
# Iteration 102, Distance 1.5056829034812518
# Iteration 103, Distance 1.4755683210161419
# Iteration 104, Distance 1.4460558302783646
# Iteration 105, Distance 1.4171335258007325
# Iteration 106, Distance 1.38878956967787
# Iteration 107, Distance 1.3610124626034812
# Iteration 108, Distance 1.3337908822502758
# Iteration 109, Distance 1.3071137232730328
# Iteration 110, Distance 1.2809704198598633
# Iteration 111, Distance 1.2553500341921986
# Iteration 112, Distance 1.2302422903715189
# Iteration 113, Distance 1.2056368851180803
# Iteration 114, Distance 1.181524037498566
# Iteration 115, Distance 1.1578936487834361
# Iteration 116, Distance 1.134735911295284
# Iteration 117, Distance 1.1120413054374079
# Iteration 118, Distance 1.0898005856120014
# Iteration 119, Distance 1.0680046790192013
# Iteration 120, Distance 1.0466446836916845
# Iteration 121, Distance 1.0257118701400412
# Iteration 122, Distance 1.005197694465699
# Iteration 123, Distance 0.9850937982169715
# Iteration 124, Distance 0.9653919803109441
# Iteration 125, Distance 0.9460841971620362
# Iteration 126, Distance 0.927162562958987
# Iteration 127, Distance 0.9086193477337074
# Iteration 128, Distance 0.8904469842835075
# Iteration 129, Distance 0.8726380652641347
# Iteration 130, Distance 0.8551853259815457
# Iteration 131, Distance 0.8380816430549642
# Iteration 132, Distance 0.8213200352774459
# Iteration 133, Distance 0.8048936609324936
# Iteration 134, Distance 0.7887958149803561
# Iteration 135, Distance 0.7730199261389715
# Iteration 136, Distance 0.7575595539980785
# Iteration 137, Distance 0.7424083857240041
# Iteration 138, Distance 0.7275602332296468
# Iteration 139, Distance 0.7130090340732728
# Iteration 140, Distance 0.6987488546554717
# Iteration 141, Distance 0.6847738787797811
# Iteration 142, Distance 0.6710784025745843
# Iteration 143, Distance 0.6576568360083019
# Iteration 144, Distance 0.6445037009139585
# Iteration 145, Distance 0.6316136286710731
# Iteration 146, Distance 0.6189813580606112
# Iteration 147, Distance 0.60660173305627
# Iteration 148, Distance 0.5944697007802239
# Iteration 149, Distance 0.5825803093819509
# Iteration 150, Distance 0.5709287060336062
# Iteration 151, Distance 0.5595101350449494
# Iteration 152, Distance 0.5483199357822541
# Iteration 153, Distance 0.5373535407975502
# Iteration 154, Distance 0.5266064740680703
# Iteration 155, Distance 0.5160743490377905
# Iteration 156, Distance 0.505752866929416
# Iteration 157, Distance 0.49563781488972425
# Iteration 158, Distance 0.4857250643682902
# Iteration 159, Distance 0.4760105693364604
# Iteration 160, Distance 0.46649036473016126
# Iteration 161, Distance 0.45716056473941297
# Iteration 162, Distance 0.44801736128048303
# Iteration 163, Distance 0.43905702240912087
# Iteration 164, Distance 0.43027589077870515
# Iteration 165, Distance 0.42167038215164826
# Iteration 166, Distance 0.4132369838807389
# Iteration 167, Distance 0.4049722534365332
# Iteration 168, Distance 0.3968728168351024
# Iteration 169, Distance 0.3889353669839093
# Iteration 170, Distance 0.38115666263965736
# Iteration 171, Distance 0.3735335299437655
# Iteration 172, Distance 0.3660628593624894
# Iteration 173, Distance 0.3587416021752482
# Iteration 174, Distance 0.3515667701317398
# Iteration 175, Distance 0.34453543472911025
# Iteration 176, Distance 0.33764472603451445
# Iteration 177, Distance 0.33089183151382795
# Iteration 178, Distance 0.32427399488355274
# Iteration 179, Distance 0.31778851498588684
# Iteration 180, Distance 0.3114327446861619
# Iteration 181, Distance 0.305204089792445
# Iteration 182, Distance 0.2991000079965887
# Iteration 183, Distance 0.29311800783665976
# Iteration 184, Distance 0.28725564767992307
# Iteration 185, Distance 0.28151053472632964
# Iteration 186, Distance 0.2758803240318075
# Iteration 187, Distance 0.2703627175511646
# Iteration 188, Distance 0.2649554632001389
# Iteration 189, Distance 0.25965635393614844
# Iteration 190, Distance 0.2544632268574189
# Iteration 191, Distance 0.24937396232026976
# Iteration 192, Distance 0.24438648307387156
# Iteration 193, Distance 0.23949875341238275
# Iteration 194, Distance 0.23470877834414697
# Iteration 195, Distance 0.23001460277725988
# Iteration 196, Distance 0.22541431072171236
# Iteration 197, Distance 0.220906024507288
# Iteration 198, Distance 0.2164879040171319
# Iteration 199, Distance 0.2121581459367929
# Iteration 200, Distance 0.20791498301804873
# Iteration 201, Distance 0.203756683357694
# Iteration 202, Distance 0.19968154969053295
# Iteration 203, Distance 0.19568791869672467
# Iteration 204, Distance 0.1917741603227942
# Iteration 205, Distance 0.18793867711633203
# Iteration 206, Distance 0.18417990357400454
# Iteration 207, Distance 0.18049630550253787
# Iteration 208, Distance 0.1768863793924878
# Iteration 209, Distance 0.17334865180463546
# Iteration 210, Distance 0.16988167876854526
# Iteration 211, Distance 0.1664840451931788
# Iteration 212, Distance 0.1631543642893152
# Iteration 213, Distance 0.15989127700352254
# Iteration 214, Distance 0.1566934514634491
# Iteration 215, Distance 0.15355958243417436
# Iteration 216, Distance 0.15048839078549558
# Iteration 217, Distance 0.14747862296978673
# Iteration 218, Distance 0.14452905051040166
# Iteration 219, Distance 0.14163846950017342
# Iteration 220, Distance 0.13880570011018495
# Iteration 221, Distance 0.13602958610797877
# Iteration 222, Distance 0.13330899438582375
# Iteration 223, Distance 0.13064281449809842
# Iteration 224, Distance 0.12802995820813723
# Iteration 225, Distance 0.12546935904397724
# Iteration 226, Distance 0.12295997186310077
# Iteration 227, Distance 0.12050077242583175
# Iteration 228, Distance 0.11809075697731446
# Iteration 229, Distance 0.1157289418377717
# Iteration 230, Distance 0.1134143630010266
# Iteration 231, Distance 0.11114607574101157
# Iteration 232, Distance 0.10892315422618644
# Iteration 233, Distance 0.10674469114165502
# Iteration 234, Distance 0.10460979731882605
# Iteration 235, Distance 0.1025176013724448
# Iteration 236, Distance 0.10046724934499335
# Iteration 237, Distance 0.09845790435810203
# Iteration 238, Distance 0.09648874627093736
# Iteration 239, Distance 0.09455897134551554
# Iteration 240, Distance 0.09266779191860965
# Iteration 241, Distance 0.09081443608021755
# Iteration 242, Distance 0.08899814735863325
# Iteration 243, Distance 0.08721818441146005
# Iteration 244, Distance 0.08547382072323115
# Iteration 245, Distance 0.08376434430876031
# Iteration 246, Distance 0.08208905742258779
# Iteration 247, Distance 0.08044727627413244
# Iteration 248, Distance 0.07883833074864867
# Iteration 249, Distance 0.07726156413367367
# Iteration 250, Distance 0.07571633285099862
# Iteration 251, Distance 0.07420200619396973
# Iteration 252, Distance 0.07271796607008608
# Iteration 253, Distance 0.07126360674869603
# Iteration 254, Distance 0.06983833461372947
# Iteration 255, Distance 0.0684415679214453
# Iteration 256, Distance 0.06707273656302618
# Iteration 257, Distance 0.06573128183176254
# Iteration 258, Distance 0.06441665619512567
# Iteration 259, Distance 0.063128323071222
# Iteration 260, Distance 0.06186575660979571
# Iteration 261, Distance 0.060628441477612594
# Iteration 262, Distance 0.059415872648055285
# Iteration 263, Distance 0.05822755519509745
# Iteration 264, Distance 0.05706300409120216
# Iteration 265, Distance 0.05592174400936721
# Iteration 266, Distance 0.05480330912917186
# Iteration 267, Distance 0.05370724294659129
# Iteration 268, Distance 0.052633098087654324
# Iteration 269, Distance 0.05158043612590978
# Iteration 270, Distance 0.05054882740338722
# Iteration 271, Distance 0.0495378508553267
# Iteration 272, Distance 0.04854709383821834
# Iteration 273, Distance 0.04757615196145536
# Iteration 274, Distance 0.046624628922220246
# Iteration 275, Distance 0.045692136343777334
# Iteration 276, Distance 0.04477829361691526
# Iteration 277, Distance 0.043882727744580866
# Iteration 278, Distance 0.04300507318967328
# Iteration 279, Distance 0.04214497172588529
# Iteration 280, Distance 0.04130207229136028
# Iteration 281, Distance 0.040476030845532515
# Iteration 282, Distance 0.03966651022862233
# Iteration 283, Distance 0.03887318002405469
# Iteration 284, Distance 0.03809571642357254
# Iteration 285, Distance 0.03733380209510306
# Iteration 286, Distance 0.03658712605320306
# Iteration 287, Distance 0.035855383532133876
# Iteration 288, Distance 0.035138275861486205
# Iteration 289, Distance 0.0344355103442568
# Iteration 290, Distance 0.03374680013736625
# Iteration 291, Distance 0.03307186413463281
# Iteration 292, Distance 0.03241042685193968
# Iteration 293, Distance 0.03176221831489374
# Iteration 294, Distance 0.031126973948611875
# Iteration 295, Distance 0.03050443446963499
# Iteration 296, Distance 0.029894345780225724
# Iteration 297, Distance 0.029296458864643042
# Iteration 298, Distance 0.028710529687344645
# Iteration 299, Distance 0.028136319093586964
# Iteration 300, Distance 0.027573592711713023
# Iteration 301, Distance 0.027022120857477343
# Iteration 302, Distance 0.026481678440337164
# Iteration 303, Distance 0.025952044871527663
# Iteration 304, Distance 0.025433003974090585
# Iteration 305, Distance 0.024924343894623092
# Iteration 306, Distance 0.02442585701673196
# Iteration 307, Distance 0.023937339876384887
# Iteration 308, Distance 0.02345859307885569
# Iteration 309, Distance 0.02298942121728869
# Iteration 310, Distance 0.02252963279293823
# Iteration 311, Distance 0.022079040137070023
# Iteration 312, Distance 0.02163745933433769
# Iteration 313, Distance 0.021204710147662703
# Iteration 314, Distance 0.020780615944701084
# Iteration 315, Distance 0.020365003625813345
# Iteration 316, Distance 0.01995770355328542
# Iteration 317, Distance 0.01955854948222764
# Iteration 318, Distance 0.01916737849258097
# Iteration 319, Distance 0.0187840309227214
# Iteration 320, Distance 0.018408350304263455
# Iteration 321, Distance 0.01804018329818971
# Iteration 322, Distance 0.017679379632213887
# Iteration 323, Distance 0.01732579203957969
# Iteration 324, Distance 0.016979276198782322
# Iteration 325, Distance 0.016639690674811858
# Iteration 326, Distance 0.016306896861309747
# Iteration 327, Distance 0.01598075892409172
# Iteration 328, Distance 0.015661143745614364
# Iteration 329, Distance 0.015347920870706456
# Iteration 330, Distance 0.015040962453290521
# Iteration 331, Distance 0.014740143204218847
# Iteration 332, Distance 0.014445340340130609
# Iteration 333, Distance 0.014156433533324082
# Iteration 334, Distance 0.013873304862659535
# Iteration 335, Distance 0.013595838765407264
# Iteration 336, Distance 0.013323921990101423
# Iteration 337, Distance 0.013057443550297003
# Iteration 338, Distance 0.01279629467929331
# Iteration 339, Distance 0.01254036878570566
# Iteration 340, Distance 0.012289561410001136
# Iteration 341, Distance 0.012043770181788984
# Iteration 342, Distance 0.011802894778156396
# Iteration 343, Distance 0.01156683688259068
# Iteration 344, Distance 0.011335500144941555
# Iteration 345, Distance 0.011108790142042997
# Iteration 346, Distance 0.010886614339211516
# Iteration 347, Distance 0.010668882052423912
# Iteration 348, Distance 0.010455504411374885
# Iteration 349, Distance 0.010246394323146446
# Iteration 350, Distance 0.01004146643669809
# Iteration 351, Distance 0.009840637107941256
# Iteration 352, Distance 0.009643824365789986
# Iteration 353, Distance 0.009450947878473996
# Iteration 354, Distance 0.009261928920906073
# Iteration 355, Distance 0.009076690342485046
# Iteration 356, Distance 0.008895156535643434
# Iteration 357, Distance 0.008717253404918458
# Iteration 358, Distance 0.008542908336822598
# Iteration 359, Distance 0.008372050170094035
# Iteration 360, Distance 0.008204609166678286
# Iteration 361, Distance 0.008040516983355422
# Iteration 362, Distance 0.007879706643681757
# Iteration 363, Distance 0.007722112510804429
# Iteration 364, Distance 0.007567670260594341
# Iteration 365, Distance 0.0074163168553857736
# Iteration 366, Distance 0.007267990518272036
# Iteration 367, Distance 0.007122630707906171
# Iteration 368, Distance 0.006980178093748474
# Iteration 369, Distance 0.006840574531878489
# Iteration 370, Distance 0.006703763041226953
# Iteration 371, Distance 0.006569687780407156
# Iteration 372, Distance 0.006438294024798564
# Iteration 373, Distance 0.006309528144305312
# Iteration 374, Distance 0.006183337581419294
# Iteration 375, Distance 0.006059670829797791
# Iteration 376, Distance 0.005938477413195989
# Iteration 377, Distance 0.005819707864948427
# Iteration 378, Distance 0.005703313707625899
# Iteration 379, Distance 0.0055892474334828905
# Iteration 380, Distance 0.005477462484810756
# Iteration 381, Distance 0.005367913235114786
# Iteration 382, Distance 0.00526055497041186
# Iteration 383, Distance 0.005155343871010843
# Iteration 384, Distance 0.00505223699359058
# Iteration 385, Distance 0.004951192253716845
# Iteration 386, Distance 0.004852168408635343
# Iteration 387, Distance 0.00475512504046425
# Iteration 388, Distance 0.004660022539651487
# Iteration 389, Distance 0.004566822088868912
# Iteration 390, Distance 0.004475485647085591
# Iteration 391, Distance 0.004385975934146092
# Iteration 392, Distance 0.004298256415466467
# Iteration 393, Distance 0.004212291287152051
# Iteration 394, Distance 0.004128045461404801
# Iteration 395, Distance 0.004045484552175423
# Iteration 396, Distance 0.003964574861147543
# Iteration 397, Distance 0.0038852833639318424
# Iteration 398, Distance 0.0038075776966368293
# Iteration 399, Distance 0.003731426142712777
# Iteration 400, Distance 0.0036567976198489728
# Iteration 401, Distance 0.003583661667444427
# Iteration 402, Distance 0.003511988434093233
# Iteration 403, Distance 0.0034417486654171924
# Iteration 404, Distance 0.003372913692112836
# Iteration 405, Distance 0.003305455418264901
# Iteration 406, Distance 0.0032393463099017294
# Iteration 407, Distance 0.0031745593837101964
# Iteration 408, Distance 0.0031110681960384813
# Iteration 409, Distance 0.003048846832113072
# Iteration 410, Distance 0.0029878698954665375
# Iteration 411, Distance 0.002928112497576853
# Iteration 412, Distance 0.002869550247610473
# Iteration 413, Distance 0.0028121592426512765
# Iteration 414, Distance 0.0027559160578040465
# Iteration 415, Distance 0.0027007977366535116
# Iteration 416, Distance 0.0026467817819121994
# Iteration 417, Distance 0.0025938461462808185
# Iteration 418, Distance 0.0025419692233499065
# Iteration 419, Distance 0.002491129838878939
# Iteration 420, Distance 0.0024413072421012867
# Iteration 421, Distance 0.0023924810972511296
# Iteration 422, Distance 0.00234463147531841
# Iteration 423, Distance 0.002297738845809055
# Iteration 424, Distance 0.002251784068892146
# Iteration 425, Distance 0.002206748387518503
# Iteration 426, Distance 0.0021626134197712797
# Iteration 427, Distance 0.00211936115137208
# Iteration 428, Distance 0.002076973928336836
# Iteration 429, Distance 0.002035434449775186
# Iteration 430, Distance 0.00199472576078505
# Iteration 431, Distance 0.0019548312455707913
# Iteration 432, Distance 0.0019157346206573043
# Iteration 433, Distance 0.0018774199282373138
# Iteration 434, Distance 0.0018398715296808357
# Iteration 435, Distance 0.0018030740990802934
# Iteration 436, Distance 0.0017670126170883213
# Iteration 437, Distance 0.001731672364760729
# Iteration 438, Distance 0.001697038917464893
# Iteration 439, Distance 0.0016630981391196583
# Iteration 440, Distance 0.0016298361763308756
# Iteration 441, Distance 0.0015972394528080663
# Iteration 442, Distance 0.0015652946637629925
# Iteration 443, Distance 0.0015339887704789348
# Iteration 444, Distance 0.0015033089950718065
# Iteration 445, Distance 0.0014732428151660202
# Iteration 446, Distance 0.0014437779588680215
# Iteration 447, Distance 0.0014149023996837182
# Iteration 448, Distance 0.001386604351698384
# Iteration 449, Distance 0.001358872264660173
# Iteration 450, Distance 0.0013316948193565115
# Iteration 451, Distance 0.0013050609229642478
# Iteration 452, Distance 0.0012789597045148725
# Iteration 453, Distance 0.0012533805104234224
# Iteration 454, Distance 0.0012283129002284266
# Iteration 455, Distance 0.0012037466422110902
# Iteration 456, Distance 0.0011796717093670382
# Iteration 457, Distance 0.0011560782751784532
# Iteration 458, Distance 0.0011329567096760528
# Iteration 459, Distance 0.0011102975754824157
# Iteration 460, Distance 0.001088091623972982
# Iteration 461, Distance 0.0010663297915092214
# Iteration 462, Distance 0.0010450031956683672
# Iteration 463, Distance 0.0010241031317634107
# Iteration 464, Distance 0.0010036210691272145
# Iteration 465, Distance 0.0009835486477410172

# %%
ks_vfi_95, _ = simulate_infinite(k0=0.95 * k_star, T_max=200, argmax_v_mat=argmax_v_mat)
ks_vfi_90, _ = simulate_infinite(k0=0.90 * k_star, T_max=200, argmax_v_mat=argmax_v_mat)
ks_vfi_80, _ = simulate_infinite(k0=0.80 * k_star, T_max=200, argmax_v_mat=argmax_v_mat)
ks_vfi_60, _ = simulate_infinite(k0=0.60 * k_star, T_max=200, argmax_v_mat=argmax_v_mat)

# %%
vfi_results = {
    "k0=0.95*kstar": speed_of_adjustment_extended_path(0.95 * k_star, ks_vfi_95),
    "k0=0.90*kstar": speed_of_adjustment_extended_path(0.90 * k_star, ks_vfi_90),
    "k0=0.80*kstar": speed_of_adjustment_extended_path(0.80 * k_star, ks_vfi_80),
    "k0=0.60*kstar": speed_of_adjustment_extended_path(0.60 * k_star, ks_vfi_60),
}

vfi_results
# Out:
# {'k0=0.95*kstar': 33,
#  'k0=0.90*kstar': 38,
#  'k0=0.80*kstar': 40,
#  'k0=0.60*kstar': 41}

# %% [markdown]
# # Perturbation Method

# %%
def f(k):
    return jnp.power(k, alpha) + ((1 - delta) * k)


def u(k, k_prime):
    return jnp.log(f(k) - k_prime)


sigma_f = -jax.grad(jax.grad(f))(k_star) / jax.grad(f)(k_star)
sigma_u = -jax.grad(jax.grad(u))(k_star, k_star) / jax.grad(u)(k_star, k_star)

nu = 1 + (1 / beta) + (sigma_f / sigma_u)

_lambdas = jnp.roots(jnp.array([1, -nu, 1 / beta])).astype(jnp.float64)
_lambda = _lambdas[_lambdas < 1][0]
_lambda
# Out:
# Array(0.89270501, dtype=float64)

# %%
T = int(jnp.floor(jnp.log(0.01) / jnp.log(_lambda)) + 1)

# %%
perturbation_results = {
    "k0=0.95*kstar": T,
    "k0=0.90*kstar": T,    
    "k0=0.80*kstar": T,    
    "k0=0.60*kstar": T
}

perturbation_results
# Out:
# {'k0=0.95*kstar': 41,
#  'k0=0.90*kstar': 41,
#  'k0=0.80*kstar': 41,
#  'k0=0.60*kstar': 41}

# %%
res = pd.DataFrame([extended_path_results, vfi_results, perturbation_results])

res.index = ["Extended Path", "Value Function Iteration", "Perturbation"]
res.columns = [
    "$k_0 = 0.95k^*$",
    "$k_0 = 0.90k^*$",
    "$k_0 = 0.80k^*$",
    "$k_0 = 0.60k^*$",
]
print(res.to_latex())
# Out:
# \begin{tabular}{lrrrr}
# \toprule
#  & $k_0 = 0.95k^*$ & $k_0 = 0.90k^*$ & $k_0 = 0.80k^*$ & $k_0 = 0.60k^*$ \\
# \midrule
# Extended Path & 39 & 39 & 40 & 40 \\
# Value Function Iteration & 33 & 38 & 40 & 41 \\
# Perturbation & 41 & 41 & 41 & 41 \\
# \bottomrule
# \end{tabular}
